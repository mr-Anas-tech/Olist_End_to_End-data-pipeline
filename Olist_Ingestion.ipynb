# %%
import pandas as pd
from google.oauth2 import service_account

# %%
key_path=r'C:\Users\QC#\Downloads\dbt-learning-493706-c3d335268113.json'
project_id="dbt-learning-493706"
dataset_id="raw_olist"
credentials=service_account.Credentials.from_service_account_file(key_path)
files={
    "raw_olist_orders":r"C:\Users\QC#\Downloads\archive\olist_orders_dataset.csv",
    "raw_olist_products":r"C:\Users\QC#\Downloads\archive\olist_products_dataset.csv",
    "raw_olist_seller":r"C:\Users\QC#\Downloads\archive\olist_sellers_dataset.csv",
    "raw_olist_geolocation":r"C:\Users\QC#\Downloads\archive\olist_geolocation_dataset.csv",
    "raw_olist_order_items":r"C:\Users\QC#\Downloads\archive\olist_order_items_dataset.csv",
    "raw_olist_payments":r"C:\Users\QC#\Downloads\archive\olist_order_payments_dataset.csv",
    "raw_olist_reviews":r"C:\Users\QC#\Downloads\archive\olist_order_reviews_dataset.csv",
    "raw_olist_customers":r"C:\Users\QC#\Downloads\archive\olist_customers_dataset.csv"
}
for table_name,file_path in files.items():
    df=pd.read_csv(file_path)
    df.to_gbq(
        destination_table=f"{dataset_id}.{table_name}",
        project_id=project_id,
        credentials=credentials,
        if_exists='replace'
    )
# Out:
# C:\Users\QC#\AppData\Local\Temp\ipykernel_8884\3615446262.py:17: FutureWarning: to_gbq is deprecated and will be removed in a future version. Please use pandas_gbq.to_gbq instead: https://pandas-gbq.readthedocs.io/en/latest/api.html#pandas_gbq.to_gbq
#   df.to_gbq(
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 3326.17it/s]
# C:\Users\QC#\AppData\Local\Temp\ipykernel_8884\3615446262.py:17: FutureWarning: to_gbq is deprecated and will be removed in a future version. Please use pandas_gbq.to_gbq instead: https://pandas-gbq.readthedocs.io/en/latest/api.html#pandas_gbq.to_gbq
#   df.to_gbq(
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 4644.85it/s]
# ...
